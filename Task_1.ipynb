# %% [markdown]
# IMPORTING LIBRARIES:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# READING DATA:

# %%
info="http://bit.ly/w-data"
data=pd.read_csv(info)
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# PLOTTING THE DATA:

# %%
# %matplotlib inline
x_axis=data['Hours']
y_axis=data['Scores']
plt.scatter(x_axis,y_axis)
plt.xlabel("Hrs/day")
plt.ylabel("Marks")
plt.show()

# %% [raw]
# LINEAR REGRESSION:

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values

x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=0)

# %%
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)

y_pred=reg.predict(x_test)

# %%
x_axis=data['Hours']
y_axis=data['Scores']
plt.scatter(x_axis,y_axis)
plt.xlabel("Hrs/day")
plt.ylabel("Marks")

plt.plot(x_test,y_pred)
plt.show()

# %% [raw]
# PREDICTION OF SCORE WHEN HOURS=9.25

# %%
hours=[[9.25]]
marks=reg.predict(h)
print(f'Predicted marks are {marks[0]}')
# Out:
# Predicted marks are 93.69173248737539

# %% [markdown]
# MEAN SQUARE ERROR:

# %%
m=metrics.mean_squared_error(y_test,y_pred)
print(f'Mean square error is {m}')
# Out:
# Mean square error is 21.598769307217456
